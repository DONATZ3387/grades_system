# %%
print("teste")
# Out:
# teste

# %%
from sign_up import signup

name, gr1, gr2 = signup()

from student_average import average

final_average = average(gr1, gr2)

from verify import verify

status = verify(final_average)

print(f'Name: {name}\nAverage: {final_average}\nStatus: {status == status}')
# Out:
# Passed
# Name: pedro
# Average: 10.0
# Status: None
